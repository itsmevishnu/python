# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('variables.csv')

# %%
data
# Out:
#       Taluka  Ratio of allocation  Ratio of distribution  \
# 0     Dahanu                 0.98                   0.79
# 1     Jawhar                 0.95                   0.91
# 2    Mokhada                 1.06                   0.83
# 3    Palghar                 0.94                   0.78
# 4   Talasari                 1.05                   0.90
# 5      Vasai                 1.03                   0.72
# 6  Vikramgad                 0.93                   0.87
# 7       Wada                 0.93                   0.81
#
#    Public distribution Ratio  Storage Ratio  Road Density  \
# 0                      94.31        7246.38         32.08
# 1                     256.42        8854.17         45.99
# 2                    4277.34       11718.75         37.13
# 3                     125.31        7990.87         19.40
# 4                    1450.12       10869.57         53.20
# 5                     367.10       11111.11        250.52
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Taluka                       8 non-null      object
#  1   Ratio of allocation          8 non-null      float64
#  2   Ratio of distribution        8 non-null      float64
#  3   Public distribution Ratio    8 non-null      float64
#  4   Storage Ratio                8 non-null      float64
#  5   Road Density                 8 non-null      float64
#  6   Population density per FPSs  8 non-null      float64
#  7   % GIS enabled FPSs           8 non-null      float64
#  8   % of EPOS availability       8 non-null      float64
#  9   Online Payment facility      8 non-null      float64
#  10  Data availability on portal  8 non-null      float64
#  11  % of complaint resolved      8 non-null      float64
# ...

# %%
data  = data.iloc[:,:-6]

# %%
del data["Online Payment facility"]
del data["Data availability on portal"]

# %%
data.describe()
# Out:
#        Ratio of allocation  Ratio of distribution  Public distribution Ratio  \
# count             8.000000               8.000000                   8.000000
# mean              0.983750               0.826250                 892.062500
# std               0.055016               0.064794                1436.184361
# min               0.930000               0.720000                  94.310000
# 25%               0.937500               0.787500                 166.935000
# 50%               0.965000               0.820000                 311.760000
# 75%               1.035000               0.877500                 651.347500
# max               1.060000               0.910000                4277.340000
#
#        Storage Ratio  Road Density  Population density per FPSs  \
# count       8.000000      8.000000                     8.000000
# mean     8893.667500     66.473750                     4.178750
# std      2582.077488     75.134629                     3.994487
# ...
